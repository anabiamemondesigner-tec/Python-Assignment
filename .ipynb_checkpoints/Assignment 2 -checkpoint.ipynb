# %% [markdown]
# # Assignment

# %% [markdown]
# ## Question 1
#
# Calculate and write the output of the following expression:
#
# **30 + 4 × 3 − 6**

# %% [markdown]
# ## BODMAS

# %%
(30 + 4 * 3 - 6)
# Out:
# 36

# %% [markdown]
# ## Question 2
#
# Calculate and write the output of the following expression:
#
# **100 ÷ 4 + 7 − 5**

# %% [markdown]
# ## BODMAS

# %%
(100 / 4 + 7 - 5)
# Out:
# 27.0

# %% [markdown]
# ## Question 3
# Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.

# %% [markdown]
# ## Convert String To Integer

# %%
a = "100"

# %%
a
# Out:
# '100'

# %%
type (a)
# Out:
# str

# %%
a = int (a)

# %%
type (a)
# Out:
# int

# %% [markdown]
# ## Question 4
#
# Create the following list and display:
#
# Cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
#
# Second city
#
# Fourth city

# %% [markdown]
# ## Indexing

# %%
Cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]

# %%
len (Cities)
# Out:
# 5

# %%
print(Cities[2])  # Lahore (2nd city)
print(Cities[4])  # Peshawar (4th city)
# Out:
# Islamabad
# Quetta

# %% [markdown]
# ## Question 5
# Create the following nested list and display:
#
# students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
#
# Ali
#
# Ayesha

# %% [markdown]
# ## Indexing

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]

# %%
print (students[0])
# Out:
# ['Ali', 20]

# %%
print (students[1])
# Out:
# ['Ayesha', 22]

# %% [markdown]
# ## Question 6
# Given list:
#
# numbers = [10, 20, 30, 40, 50, 60, 70]
#
# Display:
#
# First 3 elements
#
# Last 3 elements

# %% [markdown]
# ## Slicing

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]

# %%
numbers[0:3]
# Out:
# [10, 20, 30]

# %%
numbers[4:]
# Out:
# [50, 60, 70]

# %% [markdown]
# ## Question 7
# Given nested list:
#
# students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
#
# Display:
#
# Name of first student
#
# Age of second student

# %% [markdown]
# ## Indexing

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]

# %%
print (students [0] [0])
# Out:
# Ali

# %%
print (students [1] [1])
# Out:
# 22

# %% [markdown]
# ## Question 8
#
# Create a list of 5 fruits and display:
#
# First fruit
#
# Last fruit

# %%
fruits = ["Strawberry" , "Dragon Fruit" , "Mango" , "Pear" , "Guava", "Blue Berry"]

# %%
print (fruits [0])
# Out:
# Strawberry

# %%
print (fruits [5])
# Out:
# Blue Berry

# %% [markdown]
# ## Question 9
#
# Create the following list and display:
#
# colors = ["Red", "Blue", "Green", "Yellow", "Black"]
#
# First color
#
# Last color
#
# using negative indexing

# %% [markdown]
# ## Indexing

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Black"]

# %%
print (colors [-5])
# Out:
# Red

# %%
print (colors [-1])
# Out:
# Black

# %% [markdown]
# ## Question 10
#
# Given nested list:
#
# marks = [["Math", 90], ["Physics", 85], ["English", 88]]
#
# Display:
#
# Subject of second student
#
# Marks of third student

# %% [markdown]
# ## Indexing

# %%
marks = [["Math", 90], ["Physics", 85], ["English", 88]]

# %%
print (marks [1] [0])
# Out:
# Physics

# %%
print (marks [2] [1])
# Out:
# 88

# %% [markdown]
# ## Assignment Completed
