# %%
print("Hello world")
# Out:
# Hello world

# %%
type("Hello world")
# Out:
# str

# %%
type(123)
# Out:
# int

# %%
type(123.456)
# Out:
# float

# %% [markdown]
# # Anabia

# %% [markdown]
# ## Anabia

# %% [markdown]
# ### Anabia

# %% [markdown]
# #### Anabia

# %% [markdown]
# ##### Anabia

# %% [markdown]
# ###### Anabia

# %%
2+3 # Add
# Out:
# 5

# %%
print(2+3)
# Out:
# 5

# %%
2-3  #Sub
# Out:
# -1

# %%
print(2-3)
# Out:
# -1

# %%
2*3  #Mul
# Out:
# 6

# %%
2**3
# Out:
# 8

# %%
10/2
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %%
10%6
# Out:
# 4

# %%
name = "Sara"

# %%
name
# Out:
# 'Sara'

# %%
"Anabia" " " "Memon"
# Out:
# 'Anabia Memon'

# %%
'''I am learning 
python'''
# Out:
# 'I am learning \npython'
